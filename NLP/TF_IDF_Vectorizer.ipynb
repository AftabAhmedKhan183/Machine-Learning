# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
document = [
    "Akarsh watch Sheryians",
    "Aftab also watch Sheryians",
    "Sheryians teach good"
]

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(document)

# %%
print("Vocabulary:")
print(vectorizer.vocabulary_)
print(vectorizer.get_feature_names_out())
# Out:
# Vocabulary:
# {'akarsh': 1, 'watch': 6, 'sheryians': 4, 'aftab': 0, 'also': 2, 'teach': 5, 'good': 3}
# ['aftab' 'akarsh' 'also' 'good' 'sheryians' 'teach' 'watch']

# %%
print("BoW matrix:")
print(X.toarray())
# Out:
# BoW matrix:
# [[0.         0.72033345 0.         0.         0.42544054 0.
#   0.54783215]
#  [0.5844829  0.         0.5844829  0.         0.34520502 0.
#   0.44451431]
#  [0.         0.         0.         0.65249088 0.38537163 0.65249088
#   0.        ]]
